# %% [markdown]
# # Import Libraries and Dataset

# %%
# %pip install openpyxl

# %%
import pandas as pd
import numpy as np

# %%
dataset_path = "/Users/zap/Library/CloudStorage/GoogleDrive-mreza034@gmail.com/My Drive/Business/Purwadhika Digital Technology School/Material/ZAP Material/Job Connector Data Science Online/JCDSOL - 020/[Material] JCDSOL - 020/Module 2 - Data Analysis/Dataset"

# %% [markdown]
# ## Import Excel File

# %%
online_retail_dataset = pd.read_excel(dataset_path + "/Online Retail.xlsx")
online_retail_dataset
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
online_retail_dataset
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# ## Import .csv File

# %%
salaries_dataset = pd.read_csv(f"{dataset_path}/Salaries.csv")
salaries_dataset
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %% [markdown]
# ## Import from Server

# %%
# %pip install requests
# Out:
# ...
#
# [notice] A new release of pip is available: 23.3.2 -> 25.1.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

# %%
api_url = "https://dummyjson.com/users" # define the url

request_response = requests.get(api_url) # access the url

request_response
# Out:
# <Response [200]>

# %%
request_response.json()
# Out:
# {'users': [{'id': 1,
#    'firstName': 'Emily',
#    'lastName': 'Johnson',
#    'maidenName': 'Smith',
#    'age': 28,
#    'gender': 'female',
#    'email': 'emily.johnson@x.dummyjson.com',
#    'phone': '+81 965-431-3024',
#    'username': 'emilys',
#    'password': 'emilyspass',
#    'birthDate': '1996-5-30',
#    'image': 'https://dummyjson.com/icon/emilys/128',
#    'bloodGroup': 'O-',
#    'height': 193.24,
#    'weight': 63.16,
#    'eyeColor': 'Green',
#    'hair': {'color': 'Brown', 'type': 'Curly'},
#    'ip': '42.48.100.32',
#    'address': {'address': '626 Main Street',
#     'city': 'Phoenix',
#     'state': 'Mississippi',
#     'stateCode': 'MS',
#     'postalCode': '29112',
#     'coordinates': {'lat': -77.16213, 'lng': -92.084824},
#     'country': 'United States'},
#    'macAddress': '47:fa:41:18:ec:eb',
#    'university': 'University of Wisconsin--Madison',
#    'bank': {'cardExpire': '03/26',
#     'cardNumber': '9289760655481815',
#     'cardType': 'Elo',
# ...

# %%
request_response.json()['users']
# Out:
# [{'id': 1,
#   'firstName': 'Emily',
#   'lastName': 'Johnson',
#   'maidenName': 'Smith',
#   'age': 28,
#   'gender': 'female',
#   'email': 'emily.johnson@x.dummyjson.com',
#   'phone': '+81 965-431-3024',
#   'username': 'emilys',
#   'password': 'emilyspass',
#   'birthDate': '1996-5-30',
#   'image': 'https://dummyjson.com/icon/emilys/128',
#   'bloodGroup': 'O-',
#   'height': 193.24,
#   'weight': 63.16,
#   'eyeColor': 'Green',
#   'hair': {'color': 'Brown', 'type': 'Curly'},
#   'ip': '42.48.100.32',
#   'address': {'address': '626 Main Street',
#    'city': 'Phoenix',
#    'state': 'Mississippi',
#    'stateCode': 'MS',
#    'postalCode': '29112',
#    'coordinates': {'lat': -77.16213, 'lng': -92.084824},
#    'country': 'United States'},
#   'macAddress': '47:fa:41:18:ec:eb',
#   'university': 'University of Wisconsin--Madison',
#   'bank': {'cardExpire': '03/26',
#    'cardNumber': '9289760655481815',
#    'cardType': 'Elo',
#    'currency': 'CNY',
# ...

# %%
for data in request_response.json()['users']:
    print(data)
# Out:
# {'id': 1, 'firstName': 'Emily', 'lastName': 'Johnson', 'maidenName': 'Smith', 'age': 28, 'gender': 'female', 'email': 'emily.johnson@x.dummyjson.com', 'phone': '+81 965-431-3024', 'username': 'emilys', 'password': 'emilyspass', 'birthDate': '1996-5-30', 'image': 'https://dummyjson.com/icon/emilys/128', 'bloodGroup': 'O-', 'height': 193.24, 'weight': 63.16, 'eyeColor': 'Green', 'hair': {'color': 'Brown', 'type': 'Curly'}, 'ip': '42.48.100.32', 'address': {'address': '626 Main Street', 'city': 'Phoenix', 'state': 'Mississippi', 'stateCode': 'MS', 'postalCode': '29112', 'coordinates': {'lat': -77.16213, 'lng': -92.084824}, 'country': 'United States'}, 'macAddress': '47:fa:41:18:ec:eb', 'university': 'University of Wisconsin--Madison', 'bank': {'cardExpire': '03/26', 'cardNumber': '9289760655481815', 'cardType': 'Elo', 'currency': 'CNY', 'iban': 'YPUXISOBI7TTHPK2BR3HAIXL'}, 'company': {'department': 'Engineering', 'name': 'Dooley, Kozey and Cronin', 'title': 'Sales Manager', 'address': {
# ...

# %%
user_dataset = pd.DataFrame(request_response.json()['users'])
user_dataset
# Out:
#     id  firstName   lastName maidenName  age  gender  \
# 0    1      Emily    Johnson      Smith   28  female
# 1    2    Michael   Williams              35    male
# 2    3     Sophia      Brown              42  female
# 3    4      James      Davis              45    male
# 4    5       Emma     Miller    Johnson   30  female
# 5    6     Olivia     Wilson              22  female
# 6    7  Alexander      Jones              38    male
# 7    8        Ava     Taylor              27  female
# 8    9      Ethan   Martinez              33    male
# 9   10   Isabella   Anderson      Davis   31  female
# 10  11       Liam     Garcia              29    male
# 11  12        Mia  Rodriguez              24  female
# 12  13       Noah  Hernandez              40    male
# 13  14  Charlotte      Lopez   Martinez   36  female
# 14  15    William   Gonzalez              32    male
# 15  16      Avery      Perez              25  female
# 16  17     Evelyn    Sanchez              37  female
# ...

# %% [markdown]
# # Export File

# %% [markdown]
# ## Export to .csv file

# %%
user_dataset.to_csv("Dataset User.csv")

# %% [markdown]
# ## Export to Excel File

# %%
user_dataset.to_excel("Dataset User yaa.xlsx")

# %% [markdown]
# # Working with Multiple Table

# %%
department_dataset = pd.read_csv(f"{dataset_path}/department_dataset.csv")
employee_dataset = pd.read_csv(f"{dataset_path}/employee_dataset.csv")

display(department_dataset, employee_dataset)
# Out:
#     ID Dept_name   location travel_required
# 0    1        HR       Pune             yes
# 1    2   Finance  Bangalore              no
# 2    3   Finance  Bangalore              no
# 3    4   Finance       Pune              no
# 4    5      Tech     Mumbai              no
# 5    6      Tech       Pune              no
# 6    7      Tech  Bangalore             yes
# 7    8        HR  Bangalore              no
# 8    9        HR       Pune              no
# 9   10        HR       Pune              no
# 10  11        HR     Mumbai              no
# 11  12        HR     Mumbai             yes
# 12  13   Finance  Bangalore             yes
# 13  14      Tech  Bangalore             yes
# 14  15      Tech     Mumbai             yes
# 15  16      Tech       Pune             yes
# 16  17      Tech  Bangalore              no
# 17  18   Finance     Mumbai              no
# 18  19        HR     Mumbai              no
# 19  20   Finance  Bangalore              no
# ...

# %%
department_dataset
# Out:
#     ID Dept_name   location travel_required
# 0    1        HR       Pune             yes
# 1    2   Finance  Bangalore              no
# 2    3   Finance  Bangalore              no
# 3    4   Finance       Pune              no
# 4    5      Tech     Mumbai              no
# 5    6      Tech       Pune              no
# 6    7      Tech  Bangalore             yes
# 7    8        HR  Bangalore              no
# 8    9        HR       Pune              no
# 9   10        HR       Pune              no
# 10  11        HR     Mumbai              no
# 11  12        HR     Mumbai             yes
# 12  13   Finance  Bangalore             yes
# 13  14      Tech  Bangalore             yes
# 14  15      Tech     Mumbai             yes
# 15  16      Tech       Pune             yes
# 16  17      Tech  Bangalore              no
# 17  18   Finance     Mumbai              no
# 18  19        HR     Mumbai              no
# 19  20   Finance  Bangalore              no
# ...

# %%
employee_dataset
# Out:
#     ID  Experience_Years  Age  Gender    Salary
# 0    1                 5   28  Female    250000
# 1    2                 1   21    Male     50000
# 2    3                 3   23  Female    170000
# 3    4                 2   22    Male     25000
# 4    5                 1   17    Male     10000
# 5    6                25   62    Male   5001000
# 6    7                19   54  Female    800000
# 7    8                 2   21  Female      9000
# 8    9                10   36  Female     61500
# 9   10                15   54  Female    650000
# 10  11                 4   26  Female    250000
# 11  12                 6   29    Male   1400000
# 12  13                14   39    Male   6000050
# 13  14                11   40    Male    220100
# 14  15                 2   23    Male      7500
# 15  16                 4   27  Female     87000
# 16  17                10   34  Female    930000
# 17  18                15   54  Female   7900000
# 18  19                 2   21    Male     15000
# ...

# %% [markdown]
# ## Merge Data Frame

# %% [markdown]
# Menggabungkan dua atau lebih dataframe berdasarkan key dimana key nya merupakan kolom/fitur/variabel

# %% [markdown]
# ### Inner Join

# %%
pd.merge(
    employee_dataset, # dataframe 1
    department_dataset, # dataframe 2
    on= 'ID'
)
# Out:
#     ID  Experience_Years  Age  Gender    Salary Dept_name   location  \
# 0    1                 5   28  Female    250000        HR       Pune
# 1    2                 1   21    Male     50000   Finance  Bangalore
# 2    3                 3   23  Female    170000   Finance  Bangalore
# 3    4                 2   22    Male     25000   Finance       Pune
# 4    5                 1   17    Male     10000      Tech     Mumbai
# 5    6                25   62    Male   5001000      Tech       Pune
# 6    7                19   54  Female    800000      Tech  Bangalore
# 7    8                 2   21  Female      9000        HR  Bangalore
# 8    9                10   36  Female     61500        HR       Pune
# 9   10                15   54  Female    650000        HR       Pune
# 10  11                 4   26  Female    250000        HR     Mumbai
# 11  12                 6   29    Male   1400000        HR     Mumbai
# 12  13                14   39    Male   6000050   Finance  Bangalore
# ...

# %%
employee_with_department_df = pd.merge(
    employee_dataset, # dataframe 1
    department_dataset, # dataframe 2
    on= 'ID',
    how= 'inner'
)

employee_with_department_df
# Out:
#     ID  Experience_Years  Age  Gender    Salary Dept_name   location  \
# 0    1                 5   28  Female    250000        HR       Pune
# 1    2                 1   21    Male     50000   Finance  Bangalore
# 2    3                 3   23  Female    170000   Finance  Bangalore
# 3    4                 2   22    Male     25000   Finance       Pune
# 4    5                 1   17    Male     10000      Tech     Mumbai
# 5    6                25   62    Male   5001000      Tech       Pune
# 6    7                19   54  Female    800000      Tech  Bangalore
# 7    8                 2   21  Female      9000        HR  Bangalore
# 8    9                10   36  Female     61500        HR       Pune
# 9   10                15   54  Female    650000        HR       Pune
# 10  11                 4   26  Female    250000        HR     Mumbai
# 11  12                 6   29    Male   1400000        HR     Mumbai
# 12  13                14   39    Male   6000050   Finance  Bangalore
# ...

# %%
employee_with_department_df1 = pd.merge(
    employee_dataset, # dataframe 1
    department_dataset[['ID', 'Dept_name']], # dataframe 2
    on= 'ID',
    how= 'inner'
)

employee_with_department_df1
# Out:
#     ID  Experience_Years  Age  Gender    Salary Dept_name
# 0    1                 5   28  Female    250000        HR
# 1    2                 1   21    Male     50000   Finance
# 2    3                 3   23  Female    170000   Finance
# 3    4                 2   22    Male     25000   Finance
# 4    5                 1   17    Male     10000      Tech
# 5    6                25   62    Male   5001000      Tech
# 6    7                19   54  Female    800000      Tech
# 7    8                 2   21  Female      9000        HR
# 8    9                10   36  Female     61500        HR
# 9   10                15   54  Female    650000        HR
# 10  11                 4   26  Female    250000        HR
# 11  12                 6   29    Male   1400000        HR
# 12  13                14   39    Male   6000050   Finance
# 13  14                11   40    Male    220100      Tech
# 14  15                 2   23    Male      7500      Tech
# ...

# %% [markdown]
# ### Left Join

# %%
employee_with_department_df = pd.merge(
    employee_dataset, # dataframe 1
    department_dataset, # dataframe 2
    on= 'ID',
    how= 'left'
)

employee_with_department_df
# Out:
#     ID  Experience_Years  Age  Gender    Salary Dept_name   location  \
# 0    1                 5   28  Female    250000        HR       Pune
# 1    2                 1   21    Male     50000   Finance  Bangalore
# 2    3                 3   23  Female    170000   Finance  Bangalore
# 3    4                 2   22    Male     25000   Finance       Pune
# 4    5                 1   17    Male     10000      Tech     Mumbai
# 5    6                25   62    Male   5001000      Tech       Pune
# 6    7                19   54  Female    800000      Tech  Bangalore
# 7    8                 2   21  Female      9000        HR  Bangalore
# 8    9                10   36  Female     61500        HR       Pune
# 9   10                15   54  Female    650000        HR       Pune
# 10  11                 4   26  Female    250000        HR     Mumbai
# 11  12                 6   29    Male   1400000        HR     Mumbai
# 12  13                14   39    Male   6000050   Finance  Bangalore
# ...

# %% [markdown]
# ### Right Join

# %%
employee_with_department_df = pd.merge(
    employee_dataset, # dataframe 1
    department_dataset, # dataframe 2
    on= 'ID',
    how= 'right'
)

employee_with_department_df
# Out:
#     ID  Experience_Years  Age  Gender    Salary Dept_name   location  \
# 0    1                 5   28  Female    250000        HR       Pune
# 1    2                 1   21    Male     50000   Finance  Bangalore
# 2    3                 3   23  Female    170000   Finance  Bangalore
# 3    4                 2   22    Male     25000   Finance       Pune
# 4    5                 1   17    Male     10000      Tech     Mumbai
# 5    6                25   62    Male   5001000      Tech       Pune
# 6    7                19   54  Female    800000      Tech  Bangalore
# 7    8                 2   21  Female      9000        HR  Bangalore
# 8    9                10   36  Female     61500        HR       Pune
# 9   10                15   54  Female    650000        HR       Pune
# 10  11                 4   26  Female    250000        HR     Mumbai
# 11  12                 6   29    Male   1400000        HR     Mumbai
# 12  13                14   39    Male   6000050   Finance  Bangalore
# ...

# %% [markdown]
# ## Join Data Frame

# %% [markdown]
# Menggabungkan dua atau lebih data frame berdasarkan posisi index yang sama
# Contoh:
# * data yang berada di posisi index 0 dataframe employee digabung dengan data yang berada di posisi index 0 dataframe department

# %%
# merubah nama kolom 'ID' di department_dataset
# karena .join() tidak bisa menggabungkan dua dataframe yang memiliki nama kolom yang sama

department_dataset_modified = department_dataset.rename(columns= {'ID': 'id'})

# %%
employee_dataset.join(department_dataset_modified)
# Out:
#     ID  Experience_Years  Age  Gender    Salary  id Dept_name   location  \
# 0    1                 5   28  Female    250000   1        HR       Pune
# 1    2                 1   21    Male     50000   2   Finance  Bangalore
# 2    3                 3   23  Female    170000   3   Finance  Bangalore
# 3    4                 2   22    Male     25000   4   Finance       Pune
# 4    5                 1   17    Male     10000   5      Tech     Mumbai
# 5    6                25   62    Male   5001000   6      Tech       Pune
# 6    7                19   54  Female    800000   7      Tech  Bangalore
# 7    8                 2   21  Female      9000   8        HR  Bangalore
# 8    9                10   36  Female     61500   9        HR       Pune
# 9   10                15   54  Female    650000  10        HR       Pune
# 10  11                 4   26  Female    250000  11        HR     Mumbai
# 11  12                 6   29    Male   1400000  12        HR     Mumbai
# ...

# %%
employee_dataset.join(
    department_dataset, # data frame yang akan di join
    rsuffix= "_Employee" # nama kolom yang baru di dataframe sebelah kanan. Berubah menjadi -> _Employee
    )
# Out:
#     ID  Experience_Years  Age  Gender    Salary  ID_Employee Dept_name  \
# 0    1                 5   28  Female    250000            1        HR
# 1    2                 1   21    Male     50000            2   Finance
# 2    3                 3   23  Female    170000            3   Finance
# 3    4                 2   22    Male     25000            4   Finance
# 4    5                 1   17    Male     10000            5      Tech
# 5    6                25   62    Male   5001000            6      Tech
# 6    7                19   54  Female    800000            7      Tech
# 7    8                 2   21  Female      9000            8        HR
# 8    9                10   36  Female     61500            9        HR
# 9   10                15   54  Female    650000           10        HR
# 10  11                 4   26  Female    250000           11        HR
# 11  12                 6   29    Male   1400000           12        HR
# ...

# %%
employee_dataset.join(
    department_dataset, # data frame yang akan di join
    how= "inner",
    rsuffix= "_2" # nama kolom yang baru di dataframe sebelah kanan. Berubah menjadi -> _Employee
)
# Out:
#     ID  Experience_Years  Age  Gender    Salary  ID_2 Dept_name   location  \
# 0    1                 5   28  Female    250000     1        HR       Pune
# 1    2                 1   21    Male     50000     2   Finance  Bangalore
# 2    3                 3   23  Female    170000     3   Finance  Bangalore
# 3    4                 2   22    Male     25000     4   Finance       Pune
# 4    5                 1   17    Male     10000     5      Tech     Mumbai
# 5    6                25   62    Male   5001000     6      Tech       Pune
# 6    7                19   54  Female    800000     7      Tech  Bangalore
# 7    8                 2   21  Female      9000     8        HR  Bangalore
# 8    9                10   36  Female     61500     9        HR       Pune
# 9   10                15   54  Female    650000    10        HR       Pune
# 10  11                 4   26  Female    250000    11        HR     Mumbai
# ...

# %% [markdown]
# ## Concatenate Data Frame

# %% [markdown]
# Cara kerja .concat() :
# * kalau kolom di antara tabel/dataframe yang di concat sama, maka menambahkan sebagai baris baru
# * kalau kolom di antara tabel/dataframe yang di concat berbeda, maka menambahkan sebagai kolom baru

# %%
dataset1 = pd.DataFrame({
    'Jakarta': [6000, 8000, 8500],
    'Bandung': [6500, 7000, 9000],
    'Tangerang': [5000, 5500, 6000]
}, index= [0, 1,2])

dataset2 = pd.DataFrame({
    'Jakarta': [7000, 8500, 10000],
    'Bandung': [16500, 9000, 2000],
    'Tangerang': [3000, 4500, 4000]
}, index= [3, 4, 5])

dataset3 = pd.DataFrame({
    'Yogyakarta': [2000, 2500, 5000],
    'Semarang': [4500, 5500, 6500],
    'Solo': [5000, 6000, 9500]
}, index = [6, 7 ,8])

display(dataset1, dataset2, dataset3)
# Out:
#    Jakarta  Bandung  Tangerang
# 0     6000     6500       5000
# 1     8000     7000       5500
# 2     8500     9000       6000
#    Jakarta  Bandung  Tangerang
# 3     7000    16500       3000
# 4     8500     9000       4500
# 5    10000     2000       4000
#    Yogyakarta  Semarang  Solo
# 6        2000      4500  5000
# 7        2500      5500  6000
# 8        5000      6500  9500

# %%
pd.concat([dataset1, dataset2]) # by default menambahkan sebagai baris baru
# Out:
#    Jakarta  Bandung  Tangerang
# 0     6000     6500       5000
# 1     8000     7000       5500
# 2     8500     9000       6000
# 3     7000    16500       3000
# 4     8500     9000       4500
# 5    10000     2000       4000

# %%
pd.concat(
    [dataset1, dataset2], 
    axis= 0 # axis = 0 -> menambahkan sebagai baris baru
)
# Out:
#    Jakarta  Bandung  Tangerang
# 0     6000     6500       5000
# 1     8000     7000       5500
# 2     8500     9000       6000
# 3     7000    16500       3000
# 4     8500     9000       4500
# 5    10000     2000       4000

# %%
pd.concat(
    [dataset1, dataset2], 
    axis= 1 # axis = 1 -> menambahkan sebagai kolom baru
)
# Out:
#    Jakarta  Bandung  Tangerang  Jakarta  Bandung  Tangerang
# 0   6000.0   6500.0     5000.0      NaN      NaN        NaN
# 1   8000.0   7000.0     5500.0      NaN      NaN        NaN
# 2   8500.0   9000.0     6000.0      NaN      NaN        NaN
# 3      NaN      NaN        NaN   7000.0  16500.0     3000.0
# 4      NaN      NaN        NaN   8500.0   9000.0     4500.0
# 5      NaN      NaN        NaN  10000.0   2000.0     4000.0

# %%
pd.concat([dataset1, dataset3]) # by default menambahkan sebagai baris baru
# Out:
#    Jakarta  Bandung  Tangerang  Yogyakarta  Semarang    Solo
# 0   6000.0   6500.0     5000.0         NaN       NaN     NaN
# 1   8000.0   7000.0     5500.0         NaN       NaN     NaN
# 2   8500.0   9000.0     6000.0         NaN       NaN     NaN
# 6      NaN      NaN        NaN      2000.0    4500.0  5000.0
# 7      NaN      NaN        NaN      2500.0    5500.0  6000.0
# 8      NaN      NaN        NaN      5000.0    6500.0  9500.0

# %%
pd.concat(
    [dataset1, dataset3],
    axis = 0
)
# Out:
#    Jakarta  Bandung  Tangerang  Yogyakarta  Semarang    Solo
# 0   6000.0   6500.0     5000.0         NaN       NaN     NaN
# 1   8000.0   7000.0     5500.0         NaN       NaN     NaN
# 2   8500.0   9000.0     6000.0         NaN       NaN     NaN
# 6      NaN      NaN        NaN      2000.0    4500.0  5000.0
# 7      NaN      NaN        NaN      2500.0    5500.0  6000.0
# 8      NaN      NaN        NaN      5000.0    6500.0  9500.0

# %%
pd.concat([dataset1, dataset2, dataset3])
# Out:
#    Jakarta  Bandung  Tangerang  Yogyakarta  Semarang    Solo
# 0   6000.0   6500.0     5000.0         NaN       NaN     NaN
# 1   8000.0   7000.0     5500.0         NaN       NaN     NaN
# 2   8500.0   9000.0     6000.0         NaN       NaN     NaN
# 3   7000.0  16500.0     3000.0         NaN       NaN     NaN
# 4   8500.0   9000.0     4500.0         NaN       NaN     NaN
# 5  10000.0   2000.0     4000.0         NaN       NaN     NaN
# 6      NaN      NaN        NaN      2000.0    4500.0  5000.0
# 7      NaN      NaN        NaN      2500.0    5500.0  6000.0
# 8      NaN      NaN        NaN      5000.0    6500.0  9500.0

# %% [markdown]
# # Pandas Operations

# %%
salaries_dataset
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
salaries_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %% [markdown]
# ## Pengecekan Missing Values (data yang hilang)

# %%
salaries_dataset.isna().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                609
# OvertimePay              4
# OtherPay                 4
# Benefits             36163
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              148654
# dtype: int64

# %%
salaries_dataset[salaries_dataset['BasePay'].isna()]
# Out:
#             Id       EmployeeName                   JobTitle  BasePay  \
# 81391    81392    Kevin P Cashman             Deputy Chief 3      NaN
# 84506    84507  Demetrya  Mullens  Licensed Vocational Nurse      NaN
# 84960    84961    Michael M Horan        Park Patrol Officer      NaN
# 90525    90526       Thomas  Tang           Police Officer 3      NaN
# 90786    90787     Michael C Hill             Deputy Sheriff      NaN
# ...        ...                ...                        ...      ...
# 110530  110531      David P Kucia           Police Officer 3      NaN
# 148646  148647       Not provided               Not provided      NaN
# 148650  148651       Not provided               Not provided      NaN
# 148651  148652       Not provided               Not provided      NaN
# 148652  148653       Not provided               Not provided      NaN
#
#         OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  \
# ...

# %%
salaries_dataset[salaries_dataset['Benefits'].isna()]
# Out:
#             Id        EmployeeName  \
# 0            1      NATHANIEL FORD
# 1            2        GARY JIMENEZ
# 2            3      ALBERT PARDINI
# 3            4   CHRISTOPHER CHONG
# 4            5     PATRICK GARDNER
# ...        ...                 ...
# 36158    36159  JOSEPHINE MCCREARY
# 148646  148647        Not provided
# 148650  148651        Not provided
# 148651  148652        Not provided
# 148652  148653        Not provided
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 36158                                       MANAGER IV       0.00
# ...

# %%
salaries_dataset['EmployeeName']
# Out:
# 0            NATHANIEL FORD
# 1              GARY JIMENEZ
# 2            ALBERT PARDINI
# 3         CHRISTOPHER CHONG
# 4           PATRICK GARDNER
#                 ...
# 148649        Roy I Tillery
# 148650         Not provided
# 148651         Not provided
# 148652         Not provided
# 148653            Joe Lopez
# Name: EmployeeName, Length: 148654, dtype: object

# %%
salaries_dataset[['EmployeeName']]
# Out:
#              EmployeeName
# 0          NATHANIEL FORD
# 1            GARY JIMENEZ
# 2          ALBERT PARDINI
# 3       CHRISTOPHER CHONG
# 4         PATRICK GARDNER
# ...                   ...
# 148649      Roy I Tillery
# 148650       Not provided
# 148651       Not provided
# 148652       Not provided
# 148653          Joe Lopez
#
# [148654 rows x 1 columns]

# %% [markdown]
# ### Pengisian Missing Values

# %% [markdown]
# Mengganti nilai 'missing value' di kolom Benefits dengan nilai 0

# %%
salaries_dataset['Benefits'] = salaries_dataset['Benefits'].fillna(value= 0)
salaries_dataset
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
salaries_dataset.isna().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                609
# OvertimePay              4
# OtherPay                 4
# Benefits                 0
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              148654
# dtype: int64

# %% [markdown]
# Challenge 1 : mengisi missing values pada kolom BasePay dengan nilai rata-rata BasePay

# %%
salaries_dataset['BasePay'] = salaries_dataset['BasePay'].fillna(value= salaries_dataset['BasePay'].mean())
salaries_dataset
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18000
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02000
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13000
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00000
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60000
# ...                                                ...           ...
# ...

# %% [markdown]
# Challenge 2 : mengisi missing values pada kolom 'Notes' dengan "Tidak Ada Catatan"

# %%
salaries_dataset['Notes'] = salaries_dataset['Notes'].fillna(value= "Tidak Ada Catatan")
salaries_dataset
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18000
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02000
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13000
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00000
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60000
# ...                                                ...           ...
# ...

# %%
salaries_dataset.isna().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                  0
# OvertimePay              4
# OtherPay                 4
# Benefits                 0
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes                    0
# Agency                   0
# Status              148654
# dtype: int64

# %%
salaries_dataset_clean = salaries_dataset.drop(columns= "Status")
salaries_dataset_clean
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18000
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02000
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13000
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00000
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60000
# ...                                                ...           ...
# ...

# %%
salaries_dataset_clean.isna().sum()
# Out:
# Id                  0
# EmployeeName        0
# JobTitle            0
# BasePay             0
# OvertimePay         4
# OtherPay            4
# Benefits            0
# TotalPay            0
# TotalPayBenefits    0
# Year                0
# Notes               0
# Agency              0
# dtype: int64

# %% [markdown]
# ## Operasi Matematika

# %%
employee_base_pay = salaries_dataset.BasePay.mean()

print(f"Rata-rata base pay yang diterima adalah {employee_base_pay}")
# Out:
# Rata-rata base pay yang diterima adalah 66325.4488404877

# %%
employee_thp_average = salaries_dataset.TotalPayBenefits.mean()

print(f"Rata-rata THP yang diterima adalah {employee_thp_average}")
# Out:
# Rata-rata THP yang diterima adalah 93692.55481056681

# %%
employee_thp_median = salaries_dataset.TotalPayBenefits.median()

print(f"Median THP yang diterima adalah {employee_thp_median}")
# Out:
# Median THP yang diterima adalah 92404.09

# %%
employee_thp_max = salaries_dataset.TotalPayBenefits.max()

print(f"Max THP yang diterima adalah {employee_thp_max}")
# Out:
# Max THP yang diterima adalah 567595.43

# %%
employee_salaries = salaries_dataset[['BasePay']] * 10
employee_salaries
# Out:
#           BasePay
# 0       1674111.8
# 1       1559660.2
# 2       2127391.3
# 3        779160.0
# 4       1344016.0
# ...           ...
# 148649        0.0
# 148650        NaN
# 148651        NaN
# 148652        NaN
# 148653        0.0
#
# [148654 rows x 1 columns]

# %%
employee_salaries = salaries_dataset[['BasePay']].apply(lambda x: x * 10)
employee_salaries
# Out:
#           BasePay
# 0       1674111.8
# 1       1559660.2
# 2       2127391.3
# 3        779160.0
# 4       1344016.0
# ...           ...
# 148649        0.0
# 148650        NaN
# 148651        NaN
# 148652        NaN
# 148653        0.0
#
# [148654 rows x 1 columns]

# %% [markdown]
# ## Data Aggregation

# %%
salaries_dataset_clean
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18000
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02000
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13000
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00000
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60000
# ...                                                ...           ...
# ...

# %% [markdown]
# Rata-rata THP per jabatan

# %%
salaries_dataset_clean.groupby(by= 'JobTitle')['TotalPayBenefits'].mean()
# Out:
# JobTitle
# ACCOUNT CLERK                                     44035.664337
# ACCOUNTANT                                        47429.268000
# ACCOUNTANT INTERN                                 29031.742917
# ACPO,JuvP, Juv Prob (SFERS)                       80266.370000
# ACUPUNCTURIST                                     67594.400000
#                                                       ...
# X-RAY LABORATORY AIDE                             52705.880385
# X-Ray Laboratory Aide                             69521.123200
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS    53632.870000
# Youth Comm Advisor                                60118.550000
# ZOO CURATOR                                       66686.560000
# Name: TotalPayBenefits, Length: 2159, dtype: float64

# %% [markdown]
# Jumlah karyawan tiap jabatan

# %%
salaries_dataset_clean.groupby(by = "JobTitle")['Id'].count()
# Out:
# JobTitle
# ACCOUNT CLERK                                      83
# ACCOUNTANT                                          5
# ACCOUNTANT INTERN                                  48
# ACPO,JuvP, Juv Prob (SFERS)                         1
# ACUPUNCTURIST                                       1
#                                                  ...
# X-RAY LABORATORY AIDE                              26
# X-Ray Laboratory Aide                             100
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS      1
# Youth Comm Advisor                                  4
# ZOO CURATOR                                         1
# Name: Id, Length: 2159, dtype: int64

# %% [markdown]
# Challenge 3 : Menampilkan jumlah karyawan tiap tahunnya

# %%
salaries_dataset_clean.groupby(by = "Year")['Id'].count()
# Out:
# Year
# 2011    36159
# 2012    36766
# 2013    37606
# 2014    38123
# Name: Id, dtype: int64

# %% [markdown]
# Challenge 4 : Menampilkan rata-rata tunjangan (benefits) tiap tahun

# %%
salaries_dataset_clean.groupby(by = "Year")['Benefits'].mean()
# Out:
# Year
# 2011        0.000000
# 2012    26439.966967
# 2013    23829.076572
# 2014    24787.000743
# Name: Benefits, dtype: float64

# %%
benefits_per_year = salaries_dataset_clean.groupby(by = "Year")['Benefits'].mean().reset_index()
benefits_per_year.rename(columns={
    'Year' : 'Tahun',
    'Benefits' : 'Rata-Rata Tunjangan'
}, inplace= True)

benefits_per_year
# Out:
#    Tahun  Rata-Rata Tunjangan
# 0   2011             0.000000
# 1   2012         26439.966967
# 2   2013         23829.076572
# 3   2014         24787.000743

# %%
def roundNumber(number):
    return np.round(number, 2)

# %%
benefits_per_year['Rata-Rata Tunjangan'] = benefits_per_year['Rata-Rata Tunjangan'].apply(roundNumber)
benefits_per_year
# Out:
#    Tahun  Rata-Rata Tunjangan
# 0   2011                 0.00
# 1   2012             26439.97
# 2   2013             23829.08
# 3   2014             24787.00

# %%
benefits_per_year['Rata-Rata Tunjangan'] = benefits_per_year['Rata-Rata Tunjangan'].apply(lambda number: np.round(number, 2))
benefits_per_year
# Out:
#    Tahun  Rata-Rata Tunjangan
# 0   2011                 0.00
# 1   2012             26439.97
# 2   2013             23829.08
# 3   2014             24787.00

# %% [markdown]
# # Pandas Functionality

# %% [markdown]
# Ada beberapa function:
# * head()
# * tail()
# * info()

# %%
salaries_dataset_clean.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       0.0  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       0.0  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       0.0  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       0.0  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       0.0  326373.19         326373.19
#
#    Year              Notes         Agency
# ...

# %%
salaries_dataset_clean.head(10)
# Out:
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       0.0  567595.43         567595.43
# ...

# %%
salaries_dataset_clean.loc[0:9]
# Out:
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       0.0  567595.43         567595.43
# ...

# %%
salaries_dataset_clean.tail()
# Out:
#             Id   EmployeeName                    JobTitle      BasePay  \
# 148649  148650  Roy I Tillery                   Custodian      0.00000
# 148650  148651   Not provided                Not provided  66325.44884
# 148651  148652   Not provided                Not provided  66325.44884
# 148652  148653   Not provided                Not provided  66325.44884
# 148653  148654      Joe Lopez  Counselor, Log Cabin Ranch      0.00000
#
#         OvertimePay  OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  \
# 148649          0.0      0.00       0.0      0.00              0.00  2014
# 148650          NaN       NaN       0.0      0.00              0.00  2014
# 148651          NaN       NaN       0.0      0.00              0.00  2014
# 148652          NaN       NaN       0.0      0.00              0.00  2014
# 148653          0.0   -618.13       0.0   -618.13           -618.13  2014
#
#                     Notes         Agency
# 148649  Tidak Ada Catatan  San Francisco
# ...

# %%
salaries_dataset_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148654 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          148654 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             148654 non-null  object
#  11  Agency            148654 non-null  object
# dtypes: float64(6), int64(2), object(4)
# memory usage: 13.6+ MB

# %%
salaries_dataset_clean.shape
# Out:
# (148654, 12)

# %% [markdown]
# ## Descriptive Statistics

# %%
salaries_dataset_clean.describe()
# Out:
#                   Id        BasePay    OvertimePay       OtherPay  \
# count  148654.000000  148654.000000  148650.000000  148650.000000
# mean    74327.500000   66325.448840    5066.059886    3648.767297
# std     42912.857795   42676.946745   11454.380559    8056.601866
# min         1.000000    -166.010000      -0.010000   -7058.590000
# 25%     37164.250000   33847.017500       0.000000       0.000000
# 50%     74327.500000   65092.190000       0.000000     811.270000
# 75%    111490.750000   94605.740000    4658.175000    4236.065000
# max    148654.000000  319275.010000  245131.880000  400184.250000
#
#             Benefits       TotalPay  TotalPayBenefits           Year
# count  148654.000000  148654.000000     148654.000000  148654.000000
# mean    18924.232839   74768.321972      93692.554811    2012.522643
# std     17165.279495   50517.005274      62793.533483       1.117538
# min       -33.890000    -618.130000       -618.130000    2011.000000
# ...

# %%
salaries_dataset_clean.describe(include= "all")
# Out:
#                    Id EmployeeName          JobTitle        BasePay  \
# count   148654.000000       148654            148654  148654.000000
# unique            NaN       110811              2159            NaN
# top               NaN    Kevin Lee  Transit Operator            NaN
# freq              NaN           13              7036            NaN
# mean     74327.500000          NaN               NaN   66325.448840
# std      42912.857795          NaN               NaN   42676.946745
# min          1.000000          NaN               NaN    -166.010000
# 25%      37164.250000          NaN               NaN   33847.017500
# 50%      74327.500000          NaN               NaN   65092.190000
# 75%     111490.750000          NaN               NaN   94605.740000
# max     148654.000000          NaN               NaN  319275.010000
#
#           OvertimePay       OtherPay       Benefits       TotalPay  \
# count   148650.000000  148650.000000  148654.000000  148654.000000
# ...

# %% [markdown]
# .unique() digunakan untuk melihat daftar nilai unik suatu kolom

# %%
salaries_dataset_clean.JobTitle.unique()
# Out:
# array(['GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY',
#        'CAPTAIN III (POLICE DEPARTMENT)',
#        'WIRE ROPE CABLE MAINTENANCE MECHANIC', ..., 'Conversion',
#        'Cashier 3', 'Not provided'], dtype=object)

# %%
len(salaries_dataset_clean.JobTitle.unique())
# Out:
# 2159

# %% [markdown]
# nunique() dipakai untuk meliaht ada berapa banyak nilai unik

# %%
salaries_dataset_clean.JobTitle.nunique()
# Out:
# 2159

# %% [markdown]
# value_counts() digunakan untuk melihat frekuensi data tiap nilai unik

# %%
salaries_dataset_clean.JobTitle.value_counts()
# Out:
# JobTitle
# Transit Operator                                  7036
# Special Nurse                                     4389
# Registered Nurse                                  3736
# Public Svc Aide-Public Works                      2518
# Police Officer 3                                  2421
#                                                   ...
# CHIEF HOUSING INSPECTOR                              1
# TRAFFIC SIGNAL OPERATOR                              1
# COURT COMPUTER FACILITIES COORDINATOR                1
# AUTOMOTIVE BODY AND FENDER WORKER SUPERVISOR I       1
# VICTIM & WITNESS TECHNICIAN                          1
# Name: count, Length: 2159, dtype: int64
